# %%
import os
import cv2

from keras.datasets import mnist
import numpy as np
from sklearn.model_selection import train_test_split
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print( y_train.dtype )
images = []
labels = []
for x in os.listdir('dataset'):
    for y in os.listdir("dataset/"+x):
        alpha = "dataset/"+x + "/" +y
        im = cv2.imread(alpha,0)
        images.append(im)
        labels.append(x)
        
images = np.array(images)
labels = np.array(labels,dtype='uint8')


X_train, X_test, Y_train, Y_test = train_test_split(images, labels, test_size=0.33, random_state=42)

print(images.dtype)
print(labels.dtype)
# Out:
# uint8
# uint8
# uint8

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = np.concatenate( [ x_train , X_train] )
y_train = np.concatenate( [ y_train , Y_train] )
x_test = np.concatenate( [ x_test , X_test] )
y_test = np.concatenate( [ y_test , Y_test] )

print( x_train.shape )
print( y_train.shape )

print( x_test.shape )
print( y_test.shape )

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(60, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=256,
          epochs=5,
          verbose=1,
          validation_data=(x_test, y_test))
model.save("train3.h5")
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# (60150, 28, 28)
# (60150,)
# (10075, 28, 28)
# (10075,)
# x_train shape: (60150, 28, 28, 1)
# 60150 train samples
# 10075 test samples
# Train on 60150 samples, validate on 10075 samples
# Epoch 1/5
# 60150/60150 [==============================] - 54s 903us/step - loss: 0.4783 - accuracy: 0.8452 - val_loss: 0.0776 - val_accuracy: 0.9760
# Epoch 2/5
# 60150/60150 [==============================] - 54s 893us/step - loss: 0.1182 - accuracy: 0.9675 - val_loss: 0.0563 - val_accuracy: 0.9828
# Epoch 3/5
# 60150/60150 [==============================] - 54s 896us/step - loss: 0.0848 - accuracy: 0.9770 - val_loss: 0.0450 - val_accuracy: 0.9845
# Epoch 4/5
# 60150/60150 [==============================] - 54s 897us/step - loss: 0.0679 - accuracy: 0.9815 - val_loss: 0.0358 - val_accuracy: 0.9883
# Epoch 5/5
# 60150/60150 [==============================] - 54s 895us/step - loss: 0.0567 - accuracy: 0.9844 - val_loss: 0.0367 - val_accuracy: 0.9882
# Test loss: 0.036730947640202925
# Test accuracy: 0.9881885647773743

# %%
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator
x_train = X_train
x_test = X_test
y_test = Y_test
y_train = Y_train


if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)




datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.5
    )

datagen.fit(x_train)



model = load_model("train1.h5")

#model.fit(x_train,y_train,epochs=10,validation_data= (x_test, y_test ) )
datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.15,
    height_shift_range=0.15,
    )

# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen.fit(x_train)

# fits the model on batches with real-time data augmentation:
model.fit_generator(datagen.flow(x_train, y_train, batch_size=48),
                    steps_per_epoch=25, epochs=10,validation_data=(x_test,y_test))



model.save("train2.h5")
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# x_train shape: (144, 28, 28, 1)
# 144 train samples
# 72 test samples
# Epoch 1/10
# 25/25 [==============================] - 2s 78ms/step - loss: 3.2432 - accuracy: 0.3800 - val_loss: 2.2436 - val_accuracy: 0.1389
# Epoch 2/10
# 25/25 [==============================] - 2s 68ms/step - loss: 1.6277 - accuracy: 0.4567 - val_loss: 2.1928 - val_accuracy: 0.2361
# Epoch 3/10
# 25/25 [==============================] - 2s 67ms/step - loss: 1.3659 - accuracy: 0.5425 - val_loss: 2.1531 - val_accuracy: 0.2778
# Epoch 4/10
# 25/25 [==============================] - 2s 71ms/step - loss: 1.2222 - accuracy: 0.5675 - val_loss: 2.1453 - val_accuracy: 0.1944
# Epoch 5/10
# 25/25 [==============================] - 2s 69ms/step - loss: 1.1221 - accuracy: 0.6283 - val_loss: 2.0952 - val_accuracy: 0.3611
# Epoch 6/10
# 25/25 [==============================] - 2s 68ms/step - loss: 0.9836 - accuracy: 0.6458 - val_loss: 2.0524 - val_accuracy: 0.4583
# Epoch 7/10
# 25/25 [==============================] - 2s 68ms/step - loss: 0.8933 - accuracy: 0.6892 - val_loss: 2.0447 - val_accuracy: 0.4167
# Epoch 8/10
# 25/25 [==============================] - 2s 67ms/step - loss: 0.8453 - accuracy: 0.7067 - val_loss: 2.1592 - val_accuracy: 0.2361
# Epoch 9/10
# 25/25 [==============================] - 2s 68ms/step - loss: 0.7971 - accuracy: 0.7225 - val_loss: 2.1039 - val_accuracy: 0.3750
# Epoch 10/10
# 25/25 [==============================] - 2s 68ms/step - loss: 0.7475 - accuracy: 0.7408 - val_loss: 2.1113 - val_accuracy: 0.3750
# Test loss: 2.1113085746765137
# Test accuracy: 0.375
